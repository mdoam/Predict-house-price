# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('kc_house_data.csv')

# %%
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
sorted_table = dataset.sort_values(['yr_built'])
sorted_table
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 4697   9126101645  20140610T000000   558000.0         4       2.00
# 2961   1947300115  20140619T000000   464000.0         3       1.00
# 12369  9138100350  20150218T000000   685000.0         4       2.00
# 15016  1703400585  20141215T000000   325000.0         3       2.00
# 5236    844000425  20141223T000000   199999.0         3       1.00
# 8732   3364900156  20150317T000000   382888.0         1       1.00
# 14001  2354300456  20150311T000000   130000.0         2       1.00
# 17182  7883601155  20140530T000000   240000.0         3       2.00
# 3131   9829200590  20141028T000000   759000.0         3       2.75
# 498    9274202270  20140818T000000   625000.0         2       1.50
# 15297  6169900545  20140625T000000  1330000.0         3       1.50
# 4397   2767602490  20140724T000000   551000.0         3       1.00
# 15046  9187200275  20150420T000000   905000.0         4       2.25
# ...

# %%
plt.scatter(dataset.price,dataset.bedrooms)
plt.title("Price vs # bedrooms")
plt.show()

# %%
plt.scatter(dataset.price,dataset.yr_built)
plt.title("Price vs Year built")
plt.show()

# %%
plt.scatter(dataset.price,dataset.sqft_living)
plt.title("Price vs Square Feet")
plt.show()

# %%
mask = ((dataset['zipcode'] == 97178)  & (dataset['yr_built'] == 2015) & (dataset['bedrooms'] == 3))
data = dataset[mask]
data
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 643    9385200045  20150512T000000   729500.0         3       2.50
# 4154   8077100031  20150422T000000   631000.0         3       2.25
# 17098  9126100346  20140617T000000   350000.0         3       2.00
# 19805  9126100765  20140801T000000   455000.0         3       1.75
# 19863  2768100510  20150402T000000   649000.0         3       2.00
# 19959  7853430690  20150127T000000   572800.0         3       2.50
# 20311  7132300525  20150411T000000   500000.0         3       1.75
# 20798   952005863  20150505T000000   643950.0         3       2.25
# 20933  2652501565  20150423T000000  1550000.0         3       3.25
# 20963  6058600220  20140731T000000   230000.0         3       1.50
# 21270  1773100541  20150417T000000   389950.0         3       2.25
#
#        sqft_living  sqft_lot  floors  waterfront  view     ...      grade  \
# 643           1660      1091     3.0           0     1     ...          9
# ...

# %%
plt.scatter(data.price,data.sqft_living)
plt.title("Price vs Square Feet")
plt.show()

# %%
X = dataset.iloc[0:10, 5].values.reshape(-1,1)
y = dataset.iloc[0:10, 2].values.reshape(-1,1)

# %%
# Fitting Linear Regression to the dataset
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.score(X, y)
# Out:
# 0.88143904035442122

# %%
# Visualising the Linear Regression results
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg.predict(X), color = 'blue')
plt.title('Price vs square feet in area 97178, built in 2015 (Linear Regression)')
plt.xlabel('square feet')
plt.ylabel('price')
plt.show()

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
poly_reg.fit(X_poly, y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
lin_reg_2.score(X_poly, y)
# Out:
# 0.88409908773341572

# %%
# Visualising the Polynomial Regression results
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Price vs square feet in area 97178, built in 2015 (Linear Regression)')
plt.xlabel('square feet')
plt.ylabel('price')
plt.show()

# %%
# Visualising the Polynomial Regression results (for higher resolution and smoother curve)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Price vs square feet in area 97178, built in 2015 (Linear Regression)')
plt.xlabel('square feet')
plt.ylabel('price')
plt.show()
